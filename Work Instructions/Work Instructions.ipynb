# %% [markdown]
# # Assignment #9 - Work Instructions

# %% [markdown]
# ## Background

# %% [markdown]
# It’s a beautiful spring day, and it’s been two weeks since you were hired as a new data engineer at Pewlett Hackard. Your first major task is a research project on employees of the corporation from the 1980s and 1990s. All that remains of the database of employees from that period are six CSV files.
#
# In this assignment, you will design the tables to hold data in the CSVs, import the CSVs into a SQL database, and answer questions about the data. In other words, you will perform data modeling, data engineering, and data analysis.

# %% [markdown]
# ## Instructions

# %% [markdown]
# This assignment is divided into three parts: data modeling, data engineering, and data analysis.

# %% [markdown]
# ## Data Modeling
#
# Inspect the CSVs and sketch out an ERD of the tables.
#
# Using a tool such as  http://www.quickdatabasediagrams.com.

# %% [markdown]
# ![Data%20Modeling%20Screenshot%20.png](attachment:Data%20Modeling%20Screenshot%20.png)

# %% [markdown]
# ## Data Engineering
# - Use the information to create a table schema for each of the six CSV files. Remember to specify data types, primary keys, foreign keys, and other constraints.
# - Import each CSV file into the corresponding SQL table

# %% [raw]
# -- Exported from QuickDBD: Specifying Data Types, Primary Keys & Foreign Keys
# -- Import CSV Files Into Corresponding SQL Table in the order listed below.
#
# CREATE TABLE titles (
#     title_id VARCHAR   NOT NULL,
#     title VARCHAR   NOT NULL,
#     PRIMARY KEY (title_id)
# );
#
# CREATE TABLE employees (
#     emp_no INT   NOT NULL,
#     emp_title_id VARCHAR NOT NULL,
#     birth_date DATE   NOT NULL,
#     first_name VARCHAR   NOT NULL,
#     last_name VARCHAR   NOT NULL,
#     sex VARCHAR   NOT NULL,
#     hire_date DATE   NOT NULL,
#     FOREIGN KEY (emp_title_id) REFERENCES titles (title_id),
#     PRIMARY KEY (emp_no)
# );
#
#
# CREATE TABLE departments (
#     dept_no VARCHAR   NOT NULL,
#     dept_name VARCHAR   NOT NULL,
#     PRIMARY KEY (dept_no)
# );
#
# CREATE TABLE dept_manager (
#     dept_no VARCHAR   NOT NULL,
#     emp_no INT   NOT NULL,
#     FOREIGN KEY (emp_no) REFERENCES employees (emp_no),
#     FOREIGN KEY (dept_no) REFERENCES departments (dept_no),
#     PRIMARY KEY (dept_no, emp_no)
# );
#
# CREATE TABLE dept_emp (
#     emp_no INT   NOT NULL,
#     dept_no VARCHAR   NOT NULL,
#     FOREIGN KEY (emp_no) REFERENCES employees (emp_no),
#     FOREIGN KEY (dept_no) REFERENCES departments (dept_no),
#     PRIMARY KEY (emp_no, dept_no)
# );
#
#
# CREATE TABLE salaries (
#     emp_no INT   NOT NULL,
#     salary INT   NOT NULL,
#     FOREIGN KEY (emp_no) REFERENCES employees (emp_no),
# 	PRIMARY KEY (emp_no)
# );

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# After completing the steps above, and creating a complete database - do the following.
#
# 1. List the following details of each employee: employee number, last name, first age, sex and salary.

# %% [raw]
# SELECT employees.emp_no, employees.last_name, employees.first_name, employees.sex, salaries.salary
# FROM employees
# JOIN salaries
# ON employees.emp_no = salaries.emp_no;

# %% [markdown]
# 2. List first name, last name, and hire date for employees who were hired in 1986.

# %% [raw]
# SELECT first_name, last_name, hire_date
# FROM employees
# WHERE hire_date BETWEEN '1/1/1986' AND '12/31/1986'
# ORDER BY hire_date;

# %% [markdown]
# 3. List the manager of each department with the following information: department number, department name, the manager's employee number, last name, first name.

# %% [raw]
# SELECT departments.dept_no, departments.dept_name, dept_manager.emp_no, employees.last_name, employees.first_name
# FROM departments
# JOIN dept_manager
# ON departments.dept_no = dept_manager.dept_no
# JOIN employees
# ON dept_manager.emp_no = employees.emp_no;

# %% [markdown]
# 4. List the department of each employee with the following information: employee number, last name, first name, and department name.

# %% [raw]
# SELECT dept_emp.emp_no, employees.last_name, employees.first_name, departments.dept_name
# FROM dept_emp
# JOIN employees
# ON dept_emp.emp_no = employees.emp_no
# JOIN departments
# ON dept_emp.dept_no = departments.dept_no;

# %% [markdown]
# 5. List first name, last name, and sex for employees whose first name is "Hercules" and last names begin with "B."

# %% [raw]
# SELECT employees.first_name, employees.last_name, employees.sex
# FROM employees
# WHERE first_name = 'Hercules'
# AND last_name Like 'B%'

# %% [markdown]
# 6. List all employees in the Sales department, including their employee number, last name, first name, and department name.

# %% [raw]
# SELECT dept_emp.emp_no, employees.last_name, employees.first_name, departments.dept_name
# FROM dept_emp
# JOIN employees
# ON dept_emp.emp_no = employees.emp_no
# JOIN departments
# ON dept_emp.dept_no = departments.dept_no
# WHERE departments.dept_name = 'Sales';

# %% [markdown]
# 7. List all employees in the Sales and Development departments, including their employee number, last name, first name, and department name.

# %% [raw]
# SELECT dept_emp.emp_no, employees.last_name, employees.first_name, departments.dept_name
# FROM dept_emp
# JOIN employees
# ON dept_emp.emp_no = employees.emp_no
# JOIN departments
# ON dept_emp.dept_no = departments.dept_no
# WHERE departments.dept_name = 'Sales'
# OR departments.dept_name = 'Development';

# %% [markdown]
# 8. In descending order, list the frequency count of employee last names, i.e., how many employees share each last name.

# %% [raw]
# SELECT last_name,
# COUNT(last_name) AS "frequency"
# FROM employees
# GROUP BY last_name
# ORDER BY
# COUNT(last_name) DESC;
